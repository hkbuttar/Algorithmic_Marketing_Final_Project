# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[1]  # adjust based on output
SRC_PATH = PROJECT_ROOT / "src"

sys.path.insert(0, str(SRC_PATH))

from sephora_recommendations import run_pipeline, show_dashboard

# %%
from sephora_recommendations import write_all_product_htmls
write_all_product_htmls()
# Out:
# Loading Sephora recommendation data from CSVs...
#   Loaded 1,632 products in 0.0s
# Writing 1,632 product dashboards to /Users/hkbuttar/Downloads/Algorithmic_Marketing_Final_Project/notebooks/independent/outputs/product_dashboards/
# This may take several minutes for the full Sephora catalog.
#   -> /Users/hkbuttar/Downloads/Algorithmic_Marketing_Final_Project/notebooks/independent/outputs/product_dashboards/Rare_Beauty_by_Selena_Gomez_Warm_Wishes_Soft_Matte_Powder_Bronzer_-_519902.html
#   -> /Users/hkbuttar/Downloads/Algorithmic_Marketing_Final_Project/notebooks/independent/outputs/product_dashboards/Sol_de_Janeiro_Mini_Cheirosa_91_Rosa_Charmosa_Body___Ha_520733.html
#   -> /Users/hkbuttar/Downloads/Algorithmic_Marketing_Final_Project/notebooks/independent/outputs/product_dashboards/Sol_de_Janeiro_Brazilian_Bum_Bum_Body_Cream_-_Sol_de_Ja_406080.html
# ...

# %%
run_pipeline()
# Out:
# ██████████████████████████████████████████████████████████████████████
#   SEPHORA — RECOMMENDATION SYSTEM (1.3)
# ██████████████████████████████████████████████████████████████████████
#
#   Loading segmentation...
#   1,632 products × 49 features
#
#   Building feature blocks...
#     A. Structural:  128 features
#     B. Sentiment:   14 features
#     C. Content:     13 features
#     D. Price:       3 features
#
#   Computing similarities...
#     structural      → 1632×1632
#     sentiment       → 1632×1632
#     content         → 1632×1632
#     price           → 1632×1632
#
#   Computing scores...
#
#   Generating CSV...
#
#   ────────────────────────────────────────────────────────────
#   VALIDATION
#   Substitute same-category: 81.9%
#   Trade-up price correct:   99.6%
#   Trade-down price correct:  99.7%
#
#   ✓ Saved: /Users/hkbuttar/Downloads/Algorithmic_Marketing_Final_Project/data/processed/Sephora/sephora_recommendations.csv  ((1632, 152))
#
# ...

# %%
show_dashboard()
# Out:
# Loading Sephora recommendation data from CSVs...
#   Loaded 1,632 products in 0.1s
# <h2 style='text-align:center; color:#1a1a1a;'>Sephora — Product Recommendation Dashboard</h2><p style='text-align:center; color:#7f8c8d;'>Select from 1,632 products. Dashboard rebuilds on each selection.</p>
# Dropdown(description='Product:', layout=Layout(width='600px'), options=(('5 SENS — Discovery Perfume Set - 5 S…
# Output()
